# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
import tokenizers
from tokenizers import normalizers
from tokenizers.pre_tokenizers import WhitespaceSplit,Split
from tokenizers import Tokenizer
from tokenizers.models import WordLevel
from tokenizers.trainers import WordLevelTrainer
from tokenizers.processors import TemplateProcessing
from tokenizers.pre_tokenizers import Punctuation, WhitespaceSplit
from tokenizers.normalizers import Lowercase, Replace
from tokenizers import Regex

# %% [markdown]
# ##Sentiment Analysis

# %%
pip install -q transformers

# %%
from transformers import pipeline
specific_model = pipeline(model="Kaludi/Reviews-Sentiment-Analysis")
resultant =[]
for sent in sents :
  output = specific_model(sent)
  x= output[0]['label']
  resultant.append([sent,x])

# %%
f = open("comment_words_amazon_neg.txt",'r')
words = f.read()
print(words)
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd
import  numpy as np
from PIL import Image
import requests

stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords = stopwords, min_font_size = 10).generate(words)
plt.figure(figsize = (10, 10), facecolor = 'white', edgecolor='blue')
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()

amazon_words_neg = (wordcloud.words_.keys())
# Out:
# i on to work for amazon with a on i worked my first day an shift and that same day as the was a my background check just went through and i any on the until the i would the it would and do a but then and nothing would not even a email your amazon up ive never been i got in a with no a a in the the in so its just on and the didnt work also they me a to work with was a day but not have i been its a me and a and where do i go for my first day the email never said what of the to go to on the first day been here since doing nothing with my theres about of us here work or we just out in the for again i just started literally days and i dont any of the so please like i dont know because i dont and my you in these people are worked in this for months got they dont the my is a so no of out for me i have of but really would like the pay out to be an when i ive been with for over a year and they are no out with all these time and its getting as as the i if people are not doing their job but the
# ...

# %%
f = open("comment_words_deloitte_neg.txt",'r')
words = f.read()
print(words)
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd
import  numpy as np
from PIL import Image
import requests

stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords = stopwords, min_font_size = 10).generate(words)
print(wordcloud.words_.keys())

plt.figure(figsize = (10, 10), facecolor = 'white', edgecolor='blue')
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()
deloitte_words_neg = (wordcloud.words_.keys())
# Out:
# one of the on my was the it was from about years and i know i have it on my but i that i a do nothing im they will it and to it is it just a that person with as when is my back and is really at deloitte i work in one of the and this year and like one of the so good on my but the is im at a im one from the off and up at my this by no is to a at deloitte but just to that i be the only person or it as i to do nothing about it dont want to get up in anything i would have to my time out was and was to be and it is and i am not to my time for this is a a i didnt get the job if had good would have just an am i i just had my with a the in the was with other would think to up with a on and would just not or not about my when i them all my were on he me something i know and when i i dont know the he with is that a or is it on for or was that a one off some and i was at a for a year there but the work was no no on to to a firm for a year this firm was a back in my i was no work and nothing they
# ...

# %%
f = open("comment_words_meta_neg.txt",'r')
words = f.read()
print(words)
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd
import  numpy as np
from PIL import Image
import requests

stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords = stopwords, min_font_size = 10).generate(words)
plt.figure(figsize = (10, 10), facecolor = 'white', edgecolor='blue')
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()

meta_words_neg = (wordcloud.words_.keys())
# Out:
# this thread is for about the and rules of this for and and to your but to keep with no point or be better for the thread how much is meta on my now im that this the job im and this just my first of experience as a of the work i was for the meta which was of the for me the company all in all i like i much but if not all of my work was on which i is a for my this thread is for about the and rules of this for and and to your but to keep with no point or be better for the thread people who at meta or any other tech companies are and people have been and new are to get in the what the do they what more can you from a if i have all this for i the but it still like a i up my my and other things that to my i i a job i to have on me at a a of my have their and here i doing i work on my and but i i to new in the through the this is than the with companies not new people from and are i have not even a my company a because i them the and they a hiring i at tech and i my at my with the of and oth
# ...

# %%
f = open("comment_words_google_neg.txt",'r')
words = f.read()
print(words)
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd
import  numpy as np
from PIL import Image
import requests

stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords = stopwords, min_font_size = 10).generate(words)
print(wordcloud.words_.keys())

plt.figure(figsize = (10, 10), facecolor = 'white', edgecolor='blue')
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()
google_words_neg = (wordcloud.words_.keys())
# Out:
# it like the people want to really if it to which of these from this the would most first is on off feel to if someone something that you dont but if you some be than a new at google someone up a google and someone up an on was to as a that more like i a on google what is with like and if im not they are or no that dont have much in with in and with a and a im in a of a im in a with and with no its a job in on off feel to if someone something that you dont but if you some be than a new at google its no to that is to there have been job and all are at this the with of people to all these jobs i have at the time been job and at this i have to with no and the time i got any of interview was in the i got was with but now they much only with no or i am for like with many i and experience which i know about or they for too many my been to me out with this and the company i with has not been very with me the only that in me are that i very the that to you in for and your to other like of exp
# ...

# %%
print(words)
# Out:
# i signed on to work for amazon with a sign on bonus i worked my first day an hour shift and promptly resigned that same day as the position was a terrible fit my background check just went through and i wasnt experiencing any issues on the website until the very end whenever i would click the checkout button it would register input and do a little loading symbol but then revert and nothing would happen not even a confirmation email whats your best amazon screw up story ive never been given fully functional equipment yesterday i got in a truck with no turn signals a shattered backup cam a tree limb size hole in the roof the climate control console punched in so its just stuck on heat and the side mirrors didnt work also they handed me a shattered uncharged phone to work with yesterday was a pretty bad day but not once have i been given functional equipment its become a joke between me and a coworker oh and where do i go for my first day the email never said what part of the warehouse 
# ...

# %% [markdown]
# ##POSITIVE WORD CLOUD

# %%
f = open("comment_words_amazon_pos.txt",'r')
words = f.read()
print(words)
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd
import  numpy as np
from PIL import Image
import requests

stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords = stopwords, min_font_size = 10).generate(words)
print(wordcloud.words_.keys())

plt.figure(figsize = (10, 10), facecolor = 'white', edgecolor='blue')
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()

amazon_words_pos = (wordcloud.words_.keys())
# Out:
# first week amazon <num>th day work love looking forward day lol  trying sign benefits trying first day click benefits z app something went wrong message want phone now days sign benefits clock got internship offer last year pending case got internship california background check run likely amazon offer based pending anyone experience anything similar believe time background check might hello looking fc really opportunity go ahead role transportation based fc anyone worked fc another business area anyone worked fc office hr work worked office quite way fc time night advice thanks reading first week fulfillment center work stow <num>pm<num>am actually picked thursday friday week <num>hr shifts  went break heard talking met theres work worried little bit made think peak ends make ends ill need work extra <num>hr shift every week im previous job years will really able overtime peak work much time year amazon will find christmas thats corporate employee goes phone give company  feel dont 
# ...

# %%
f = open("comment_words_deloitte_pos.txt",'r')
words = f.read()
print(words)
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd
import  numpy as np
from PIL import Image
import requests

stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords = stopwords, min_font_size = 10).generate(words)
print(wordcloud.words_.keys())

plt.figure(figsize = (10, 10), facecolor = 'white', edgecolor='blue')
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()
deloitte_words_pos = (wordcloud.words_.keys())
# Out:
# im pretty concerned someone please advice id really appreciate  accepted internship offer offer background check   think contact recruiter let know  please help im really thank got asked take digital interview today full developer job tips will technical background experience will joining firm toronto next year fresh graduate curious know culture specifically ma im interviewing position deloitte digital software engineer  whats balance digital use utilization everyone seems thats deloitte asked make plan two months ago made plan put worked yesterday told made areas need still plan says still need work areas think will fired soon soon asking another job going leave job wondering long wait thanks recently joined deloitte need either account deloitte plan keep dont much background keep seeing layoffs canada wondering work audit assurance role someone point role pay etc helpful hey folks anyone know deloitte us noticed im sure firms  well  looking switch within consulting line currently 
# ...

# %%
f = open("comment_words_meta_pos.txt",'r')
words = f.read()
print(words)
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd
import  numpy as np
from PIL import Image
import requests

stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords = stopwords, min_font_size = 10).generate(words)
print(wordcloud.words_.keys())

plt.figure(figsize = (10, 10), facecolor = 'white', edgecolor='blue')
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()
meta_words_pos = (wordcloud.words_.keys())
# Out:
#  still make meta posts existing threads relevant topic dedicated threads feel strongly enough something pming mods space focusing issues discussed open  thread posted first day every month previous monthly metathreads found herehttpswwwredditcomrcscareerquestionssearchqmonthlymetathreadrestrict_sronsortnewtall hey im currently bachelors development computer science looking big software companies microsoft meta etc will able using skills degree open general note level salary senior positions point post ask salary level jobs make many people comments understand internships said companies apply senior positions theres job title internships enough experience least try interview doesnt mean im actually applying    im little resume bit new grad lot experience level roles swe even senior companies internships years experience trying im really trying understand  background may bachelors science month internships done software engineering internships meta one internships took senior years met
# ...

# %%
f = open("comment_words_google_pos.txt",'r')
words = f.read()
print(words)
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd
import  numpy as np
from PIL import Image
import requests

stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords = stopwords, min_font_size = 10).generate(words)
print(wordcloud.words_.keys())

plt.figure(figsize = (10, 10), facecolor = 'white', edgecolor='blue')
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()
google_words_pos = (wordcloud.words_.keys())
# Out:
#                                                                                                      now using github much next guy use need already know needs need sure time maybe dont google time  thats rant think now something different  love part app cant  rant thread   midnight every friday best time previous friday rant threads found hi  im data developer im first year cs years ive quite skills think dont know job even list  data stuff using python use tech  stuff python web using python  use google app stuff google google  web development build end using backend use either  build actually experience company currently  im course  think dont know position type jobs  thinking  id data stuff know little bit learning enough learning engineer data  dont want become full stack developer dont want skills well think data web either lot data good thing  id think data analyst support data development skills data  cant find dont want web development advice appreciated skills  currently da
# ...

# %%
import collections
list_positive=[]
list_positive.extend(list(amazon_words_pos))
list_positive.extend(list(deloitte_words_pos))
list_positive.extend(list(meta_words_pos))
list_positive.extend(list(google_words_pos))
counter_positive = collections.Counter(list_positive)

positive_words=[]
for i in counter_positive.most_common(100):
    positive_words.append(i[0])

positive_words
# Out:
# ['work',
#  'im',
#  'day',
#  'job',
#  'will',
#  'time',
#  'know',
#  'got',
#  'week',
#  'anyone',
#  'one',
#  'go',
#  'still',
#  'ive',
#  'year',
#  'pay',
#  'say',
#  'need',
#  'take',
#  'back',
#  'dont',
#  'now',
#  'position',
#  'thank',
#  'start',
#  'said',
#  'manager',
#  'new',
#  'people',
#  'question',
#  'want',
#  'really',
#  'getting',
#  'working',
#  'able',
#  'month',
#  'first',
#  'going',
#  'thing',
#  'well',
#  'help',
#  'applied',
#  'see',
#  'use',
#  'long',
#  'anything',
#  'role',
#  'much',
#  'even',
#  'think',
#  'id',
#  'good',
#  'something',
#  'worked',
#  'email',
#  'interview',
#  'x num',
#  'num b',
#  'keep',
#  'apply',
#  'someone',
#  'started',
#  'find',
#  'around',
#  'looking',
#  'end',
#  'offer',
#  'experience',
#  'may',
#  'better',
#  'feel',
#  'asked',
#  'us',
#  'company',
#  'lot',
#  'many',
#  'etc',
#  'application',
#  'look',
#  'hr',
#  'told',
#  'another',
#  'make',
#  'put',
#  'way',
# ...

# %%
import collections
list_negative=[]
list_negative.extend(list(amazon_words_neg))
list_negative.extend(list(deloitte_words_neg))
list_negative.extend(list(meta_words_neg))
list_negative.extend(list(google_words_neg))
counter_negative = collections.Counter(list_negative)

negative_words=[]
for i in counter_negative.most_common(60):
    negative_words.append(i[0])
negative_words
# Out:
# ['im',
#  'work',
#  'dont',
#  'even',
#  'time',
#  'ive',
#  'job',
#  'people',
#  'really',
#  'feel',
#  'know',
#  'one',
#  'got',
#  'never',
#  'year',
#  'new',
#  'will',
#  'now',
#  'first',
#  'something',
#  'want',
#  'think',
#  'much',
#  'experience',
#  'hr',
#  'back',
#  'cant',
#  'working',
#  'anything',
#  'didnt',
#  'getting',
#  'still',
#  'going',
#  'manager',
#  'nothing',
#  'someone',
#  'well',
#  'keep',
#  'point',
#  'good',
#  'company',
#  'interview',
#  'things',
#  'day',
#  'amazon',
#  'shift',
#  'told',
#  'go',
#  'hours',
#  'said',
#  'email',
#  'start',
#  'worked',
#  'case',
#  'every',
#  'last',
#  'anyone',
#  'need',
#  'literally',
#  'months']
